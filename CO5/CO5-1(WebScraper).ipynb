# %% [markdown]
# **AIM:** Implement a program to scrap the web page of any popular website – suggested python package is scrappy (ensure ethical conduct).

# %%
#webpage scraper
from bs4 import BeautifulSoup
import csv
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
webpage=requests.get("https://www.nykaa.com/brands/lakme/c/604?ptype=brand&id=604&root=brand_menu,top_brands,Lakme")

# %%
webpage
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=5.0" name="viewport"/>
#   <meta content="#fff" name="theme-color"/>
#   <meta content="NykaaFrontendTeam" name="author"/>
#   <link href="//images-static.nykaa.com/media/favicon/default/nykaa_favicon_a.png" rel="icon" type="image/x-icon"/>
#   <link href="https://www.nykaa.com/brands/lakme/c/604" rel="canonical"/>
#   <title data-react-helmet="true">
#    Buy Lakme products online at best price on Nykaa | Nykaa
#   </title>
#   <meta content="Buy Lakme products online at best price on Nykaa  -  India's online cosmetics store. Cash on Delivery &amp; Free shipping available on Lakme beauty products." data-react-helmet="true" name="description"/>
#   <meta content="Lakme, Lakme Products, Lakme Cosmetics, Lakme Beauty Products, Buy Lakme Products online India, Lakme Products price india" data-react-helmet="true" name="keywords"/>
# ...

# %%
names = soup.find_all('div',class_='css-10zjw4o')

# %%
names
# Out:
# [<div class="css-10zjw4o">Lakme Absolute Matte Ultimate Lip Color with Argan Oil</div>,
#  <div class="css-10zjw4o">Lakme Absolute Blur Perfect Makeup Primer</div>,
#  <div class="css-10zjw4o">Lakme Absolute Skin Natural Mousse Mattreal Foundation</div>,
#  <div class="css-10zjw4o">Lakme Eyeconic Curling Mascara</div>,
#  <div class="css-10zjw4o">Lakme Vitamin C AM PM Routine</div>,
#  <div class="css-10zjw4o">Lakme Peach Milk Soft Creme Moisturizer</div>,
#  <div class="css-10zjw4o">Lakme Absolute Perfect Radiance AM PM Routine</div>,
#  <div class="css-10zjw4o">Lakme Facewash Strawberry + Kiwi + Lemon Combo</div>,
#  <div class="css-10zjw4o">Lakme Absolute Infinity Eye Shadow Palette</div>,
#  <div class="css-10zjw4o">Lakme Absolute Liquid Highlighter</div>,
#  <div class="css-10zjw4o">Lakme Forever Matte Liquid Lip Color</div>,
#  <div class="css-10zjw4o">Lakme Complexion Care Face CC Cream</div>,
#  <div class="css-10zjw4o">Lakme Insta Eye Liner</div>,
# ...

# %%
Lakme_products =[]
for i in range(0,len(names)):
  Lakme_products.append(names[i].get_text())

# %%
Lakme_products
# Out:
# ['Lakme Absolute Matte Ultimate Lip Color with Argan Oil',
#  'Lakme Absolute Blur Perfect Makeup Primer',
#  'Lakme Absolute Skin Natural Mousse Mattreal Foundation',
#  'Lakme Eyeconic Curling Mascara',
#  'Lakme Vitamin C AM PM Routine',
#  'Lakme Peach Milk Soft Creme Moisturizer',
#  'Lakme Absolute Perfect Radiance AM PM Routine',
#  'Lakme Facewash Strawberry + Kiwi + Lemon Combo',
#  'Lakme Absolute Infinity Eye Shadow Palette',
#  'Lakme Absolute Liquid Highlighter',
#  'Lakme Forever Matte Liquid Lip Color',
#  'Lakme Complexion Care Face CC Cream',
#  'Lakme Insta Eye Liner',
#  'Lakme Eyeconic Kajal',
#  'Lakme Color Crush Nail Art',
#  'Lakme Eyeconic Kajal Twin Pack - Deep Black',
#  'Lakme Lip Love Chapstick SPF 15',
#  'Lakme Absolute Blur Perfect Makeup Primer - Mini',
#  'Lakme 9 To 5 Primer + Gloss Nail Color',
#  'Lakme 9 to 5 Primer + Matte Powder Foundation Compact']

# %%
price = soup.find_all('span',class_='css-18tn768')

# %%
price
# Out:
# [<span class="css-18tn768">₹400</span>,
#  <span class="css-18tn768">₹503</span>,
#  <span class="css-18tn768">₹499</span>,
#  <span class="css-18tn768">₹375</span>,
#  <span class="css-18tn768">₹1347</span>,
#  <span class="css-18tn768">₹110</span>,
#  <span class="css-18tn768">₹1547</span>,
#  <span class="css-18tn768">₹665</span>,
#  <span class="css-18tn768">₹698</span>,
#  <span class="css-18tn768">₹650</span>,
#  <span class="css-18tn768">₹295</span>,
#  <span class="css-18tn768">₹314</span>,
#  <span class="css-18tn768">₹130</span>,
#  <span class="css-18tn768">₹248</span>,
#  <span class="css-18tn768">₹140</span>,
#  <span class="css-18tn768">₹320</span>,
#  <span class="css-18tn768">₹150</span>,
#  <span class="css-18tn768">₹299</span>,
#  <span class="css-18tn768">₹162</span>,
#  <span class="css-18tn768">₹518</span>]

# %%
Price =[]
for i in range(0,len(price)):
 Price.append(price[i].get_text())

# %%
Price
# Out:
# ['₹400',
#  '₹503',
#  '₹499',
#  '₹375',
#  '₹1347',
#  '₹110',
#  '₹1547',
#  '₹665',
#  '₹698',
#  '₹650',
#  '₹295',
#  '₹314',
#  '₹130',
#  '₹248',
#  '₹140',
#  '₹320',
#  '₹150',
#  '₹299',
#  '₹162',
#  '₹518']

# %%
offer = soup.find_all('span',class_='css-3puvc6')

# %%
offer
# Out:
# [<span class="css-3puvc6">50% Off</span>,
#  <span class="css-3puvc6">33% Off</span>,
#  <span class="css-3puvc6">40% Off</span>,
#  <span class="css-3puvc6">30% Off</span>,
#  <span class="css-3puvc6">10% Off</span>,
#  <span class="css-3puvc6">10% Off</span>,
#  <span class="css-3puvc6">10% Off</span>,
#  <span class="css-3puvc6">10% Off</span>,
#  <span class="css-3puvc6">10% Off</span>]

# %%
off_rate =[]
for i in range(0,len(offer)):
 off_rate.append(offer[i].get_text())

# %%
import pandas as pd
df=pd.DataFrame()

# %%
df['Lakme_Products']=Lakme_products
df['Price']=Price

# %%
df
# Out:
#                                        Lakme_Products  Price
# 0   Lakme Absolute Matte Ultimate Lip Color with A...   ₹400
# 1           Lakme Absolute Blur Perfect Makeup Primer   ₹503
# 2   Lakme Absolute Skin Natural Mousse Mattreal Fo...   ₹499
# 3                      Lakme Eyeconic Curling Mascara   ₹375
# 4                       Lakme Vitamin C AM PM Routine  ₹1347
# 5             Lakme Peach Milk Soft Creme Moisturizer   ₹110
# 6       Lakme Absolute Perfect Radiance AM PM Routine  ₹1547
# 7      Lakme Facewash Strawberry + Kiwi + Lemon Combo   ₹665
# 8          Lakme Absolute Infinity Eye Shadow Palette   ₹698
# 9                   Lakme Absolute Liquid Highlighter   ₹650
# 10               Lakme Forever Matte Liquid Lip Color   ₹295
# 11                Lakme Complexion Care Face CC Cream   ₹314
# 12                              Lakme Insta Eye Liner   ₹130
# 13                               Lakme Eyeconic Kajal   ₹248
# ...

# %%
df.to_csv('Lakme_products.csv',index=False)

# %%
pd.read_csv("Lakme_products.csv")
# Out:
#                                        Lakme_Products  Price
# 0   Lakme Absolute Matte Ultimate Lip Color with A...   ₹400
# 1           Lakme Absolute Blur Perfect Makeup Primer   ₹503
# 2   Lakme Absolute Skin Natural Mousse Mattreal Fo...   ₹499
# 3                      Lakme Eyeconic Curling Mascara   ₹375
# 4                       Lakme Vitamin C AM PM Routine  ₹1347
# 5             Lakme Peach Milk Soft Creme Moisturizer   ₹110
# 6       Lakme Absolute Perfect Radiance AM PM Routine  ₹1547
# 7      Lakme Facewash Strawberry + Kiwi + Lemon Combo   ₹665
# 8          Lakme Absolute Infinity Eye Shadow Palette   ₹698
# 9                   Lakme Absolute Liquid Highlighter   ₹650
# 10               Lakme Forever Matte Liquid Lip Color   ₹295
# 11                Lakme Complexion Care Face CC Cream   ₹314
# 12                              Lakme Insta Eye Liner   ₹130
# 13                               Lakme Eyeconic Kajal   ₹248
# ...

# %% [markdown]
# **RESULT:** The program is successfullt executed and the output is verified.
